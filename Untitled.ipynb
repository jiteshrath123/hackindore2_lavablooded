# %%
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
genome_tags = pd.read_csv("genome-tags.csv") 
# Preview the first 5 lines of the loaded data 
genome_tags.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
genome_scores = pd.read_csv('genome-scores.csv')
genome_scores.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02500
# 1        1      2    0.02500
# 2        1      3    0.05775
# 3        1      4    0.09675
# 4        1      5    0.14675

# %%
genome_scores.describe()
# Out:
#             movieId         tagId     relevance
# count  1.170977e+07  1.170977e+07  1.170977e+07
# mean   2.584297e+04  5.645000e+02  1.164833e-01
# std    3.467615e+04  3.256254e+02  1.542463e-01
# min    1.000000e+00  1.000000e+00  2.500000e-04
# 25%    2.926000e+03  2.827500e+02  2.425000e-02
# 50%    6.017000e+03  5.645000e+02  5.650000e-02
# 75%    4.606200e+04  8.462500e+02  1.415000e-01
# max    1.311700e+05  1.128000e+03  1.000000e+00

# %%
genome_tags_merge = pd.merge(genome_scores,genome_tags,on='tagId')

# %%
genome_tags_merge.head()
# Out:
#    movieId  tagId  relevance  tag
# 0        1      1    0.02500  007
# 1        2      1    0.03975  007
# 2        3      1    0.04350  007
# 3        4      1    0.03725  007
# 4        5      1    0.04200  007

# %%
genome_tags_merge[genome_tags_merge['movieId'] == 1]
# Out:
#           movieId  tagId  relevance                 tag
# 0               1      1    0.02500                 007
# 10381           1      2    0.02500        007 (series)
# 20762           1      3    0.05775        18th century
# 31143           1      4    0.09675               1920s
# 41524           1      5    0.14675               1930s
# 51905           1      6    0.21700               1950s
# 62286           1      7    0.06700               1960s
# 72667           1      8    0.26275               1970s
# 83048           1      9    0.26200               1980s
# 93429           1     10    0.03200        19th century
# 103810          1     11    0.57700                  3d
# 114191          1     12    0.11625                70mm
# 124572          1     13    0.18800                 80s
# 134953          1     14    0.00800                9/11
# 145334          1     15    0.03675             aardman
# 155715          1     16    0.28175     aardman studios
# ...

# %%
movies = pd.read_csv('movies.csv')

# %%
movies['movieId'].nunique()
# Out:
# 27278

# %%
movies_genome_merge = pd.merge(genome_tags_merge,movies,on='movieId')

# %%
len(movies_genome_merge)
#movies_genome_merge['movieId'].nunique()
# Out:
# 11709768

# %%
movies_genome_merge.tail(5)
# Out:
#           movieId  tagId  relevance      tag             title  genres
# 11709763   131170   1124    0.58775  writing  Parallels (2015)  Sci-Fi
# 11709764   131170   1125    0.01075    wuxia  Parallels (2015)  Sci-Fi
# 11709765   131170   1126    0.01575     wwii  Parallels (2015)  Sci-Fi
# 11709766   131170   1127    0.11450   zombie  Parallels (2015)  Sci-Fi
# 11709767   131170   1128    0.02175  zombies  Parallels (2015)  Sci-Fi

# %%
#creating list of all tags and genres to be added as columns in main datafram
movies['genres'] = movies['genres'].str.split('|')

# %%
# movies_genome_merge['tagId'].nunique()
movies_genome_merge['genres'] = movies_genome_merge['genres'].str.split('|')

# %%
# movies_genome_merge.head()
len(movies_genome_merge)
# Out:
# 11709768

# %%
tag_id = movies_genome_merge['tagId']
# tag_id.head()
len(tag_id)
# Out:
# 11709768

# %%
tag_id.drop_duplicates(inplace = True)

# %%
# tag_id.describe()
len(tag_id)
# Out:
# 1128

# %%
# len(movies_genome_merge)
movies_merge_temp = movies_genome_merge[:]
len(movies_merge_temp)
# Out:
# 11709768

# %%
merge_pivot = movies_merge_temp.pivot(index ='movieId',columns='tagId',values = 'relevance')

# %%
merge_pivot.to_csv('merge_pivot.csv')

# %%
len(merge_pivot)
# Out:
# 10381

# %%
merge_pivot.head()
# Out:
# tagId       1        2        3        4        5        6        7     \
# movieId
# 1        0.02500  0.02500  0.05775  0.09675  0.14675  0.21700  0.06700
# 2        0.03975  0.04375  0.03775  0.04800  0.11025  0.07250  0.04775
# 3        0.04350  0.05475  0.02800  0.07700  0.05400  0.06850  0.05600
# 4        0.03725  0.03950  0.03675  0.03100  0.06825  0.04050  0.02325
# 5        0.04200  0.05275  0.05925  0.03675  0.07525  0.12525  0.02850
#
# tagId       8        9        10     ...        1119     1120     1121  \
# movieId                              ...
# 1        0.26275  0.26200  0.03200   ...     0.03950  0.01800  0.04575
# 2        0.10975  0.09925  0.02050   ...     0.04175  0.01925  0.01725
# 3        0.18500  0.04925  0.02675   ...     0.04150  0.02675  0.02775
# 4        0.08700  0.05125  0.03025   ...     0.05750  0.03375  0.02275
# 5        0.08500  0.02950  0.02875   ...     0.04250  0.02825  0.02150
#
# ...

# %%
type(merge_pivot.iloc[1])
# Out:
# pandas.core.series.Series

# %%
# testing movie id be 1
my_movie = merge_pivot.iloc[1]

# %%
merge_pivot_temp = merge_pivot[:]

# %%
merge_pivot_temp.head()
# Out:
# tagId       1        2        3        4        5        6        7     \
# movieId
# 1        0.02500  0.02500  0.05775  0.09675  0.14675  0.21700  0.06700
# 2        0.03975  0.04375  0.03775  0.04800  0.11025  0.07250  0.04775
# 3        0.04350  0.05475  0.02800  0.07700  0.05400  0.06850  0.05600
# 4        0.03725  0.03950  0.03675  0.03100  0.06825  0.04050  0.02325
# 5        0.04200  0.05275  0.05925  0.03675  0.07525  0.12525  0.02850
#
# tagId       8        9        10     ...        1119     1120     1121  \
# movieId                              ...
# 1        0.26275  0.26200  0.03200   ...     0.03950  0.01800  0.04575
# 2        0.10975  0.09925  0.02050   ...     0.04175  0.01925  0.01725
# 3        0.18500  0.04925  0.02675   ...     0.04150  0.02675  0.02775
# 4        0.08700  0.05125  0.03025   ...     0.05750  0.03375  0.02275
# 5        0.08500  0.02950  0.02875   ...     0.04250  0.02825  0.02150
#
# ...

# %%
sorted_series = (((merge_pivot_temp - my_movie)**2).sum(axis = 1)).sort_values(ascending = True)

# %%
sorted_series.head()
# Out:
# movieId
# 2         0.000000
# 2054     10.060572
# 2429     11.716365
# 46972    14.016617
# 40851    14.396257
# dtype: float64

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                               genres
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]

# %%
movies_new = movies.drop(['genres'],axis = 1)

# %%
movies_new
# Out:
#        movieId                                              title
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# ...

# %%
final_merge = pd.merge(movies_new,merge_pivot,on='movieId')

# %%
final_merge.head()
# Out:
#    movieId                               title        1        2        3  \
# 0        1                    Toy Story (1995)  0.02500  0.02500  0.05775
# 1        2                      Jumanji (1995)  0.03975  0.04375  0.03775
# 2        3             Grumpier Old Men (1995)  0.04350  0.05475  0.02800
# 3        4            Waiting to Exhale (1995)  0.03725  0.03950  0.03675
# 4        5  Father of the Bride Part II (1995)  0.04200  0.05275  0.05925
#
#          4        5        6        7        8   ...        1119     1120  \
# 0  0.09675  0.14675  0.21700  0.06700  0.26275   ...     0.03950  0.01800
# 1  0.04800  0.11025  0.07250  0.04775  0.10975   ...     0.04175  0.01925
# 2  0.07700  0.05400  0.06850  0.05600  0.18500   ...     0.04150  0.02675
# 3  0.03100  0.06825  0.04050  0.02325  0.08700   ...     0.05750  0.03375
# 4  0.03675  0.07525  0.12525  0.02850  0.08500   ...     0.04250  0.02825
#
#       1121     1122     1123     1124     1125     1126     1127     1128
# ...

# %%
final_merge.to_csv('final_merge.csv')

# %% [markdown]
# ## so far we have created a final_merge dataset for our file

# %% [markdown]
# ## now using this datset in the algorithm as follows

# %% [markdown]
# ### step1: using minimum distance value to compute the top 25 closest choices

# %%
# testing movie id be 1
my_movie = final_merge.iloc[1]

# %%
# sorted_min_series = (((final_merge - my_movie)**2).sum(axis = 1)).sort_values(ascending = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\kruti\appdata\local\programs\python\python36\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1496         try:
# -> 1497             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1498         except TypeError:
#
# c:\users\kruti\appdata\local\programs\python\python36\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# c:\users\kruti\appdata\local\programs\python\python36\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# ...
